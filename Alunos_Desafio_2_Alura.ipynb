# %% [markdown]
# <a href="https://colab.research.google.com/github/renantgb23/Desafio-Alura---Alunos-Aprovados/blob/main/Alunos_Desafio_2_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'

df_alunos = pd.read_csv(url)

# %%
df_alunos.head()
# Out:
#     Nome  Idade  Notas  Aprovado
# 0    Ary     20    7.5      True
# 1    Ana     18    NaN     False
# 2  Cátia     27    2.5     False
# 3  Denis     18    5.0     False
# 4   Beto     21   10.0      True

# %% [markdown]
# **1) Crie uma coluna chamada "Pontos_extras" que contenha os pontos extras de cada aluno, ou seja, 40% da nota atual deles.**

# %%
# Verificando se há dados nulos

df_alunos.isnull().sum()
# Out:
# Nome        0
# Idade       0
# Notas       6
# Aprovado    0
# dtype: int64

# %%
# Tratando dados nulos

df_alunos = df_alunos.fillna(0)
df_alunos.isnull().sum()
# Out:
# Nome        0
# Idade       0
# Notas       0
# Aprovado    0
# dtype: int64

# %%
# Criando a coluna Pontos Extras

df_alunos['Pontos_extras'] = df_alunos['Notas'].apply(lambda x: x * 0.4)

df_alunos.head()
# Out:
#     Nome  Idade  Notas  Aprovado  Pontos_extras
# 0    Ary     20    7.5      True            3.0
# 1    Ana     18    0.0     False            0.0
# 2  Cátia     27    2.5     False            1.0
# 3  Denis     18    5.0     False            2.0
# 4   Beto     21   10.0      True            4.0

# %% [markdown]
# **2) Crie mais uma coluna, chamada "Notas_finais" que possua as notas de cada aluno somada com os pontos extras.**

# %%
# Criando coluna Notas Finais

df_alunos['Notas_Finais'] = df_alunos['Notas'] + df_alunos['Pontos_extras']

df_alunos
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_Finais
# 0         Ary     20    7.5      True           3.00         10.50
# 1         Ana     18    0.0     False           0.00          0.00
# 2       Cátia     27    2.5     False           1.00          3.50
# 3       Denis     18    5.0     False           2.00          7.00
# 4        Beto     21   10.0      True           4.00         14.00
# 5       Bruna     23    0.0     False           0.00          0.00
# 6        Dara     21    7.0      True           2.80          9.80
# 7      Carlos     19    6.0      True           2.40          8.40
# 8       Alice     35    5.6     False           2.24          7.84
# 9       Vitor     28    0.0     False           0.00          0.00
# 10     Daniel     21    0.0     False           0.00          0.00
# 11       Igor     24    4.5     False           1.80          6.30
# 12  Sthefanie     26    9.5      True           3.80         13.30
# ...

# %% [markdown]
# **3) Como houve uma pontuação extra, alguns alunos que não tinham sido aprovados antes podem ter sido aprovados agora. Com base nisso, crie uma coluna chamada "Aprovado_final" com os seguintes valores:**
#
# **True:** caso o aluno esteja aprovado (nota final deve ser maior ou igual a 6);
#
# **False:** caso o aluno esteja reprovado (nota final deve ser menor que 6).

# %%
df_alunos['Aprovado_Final'] = df_alunos['Notas_Finais'].apply(lambda x: True if x >= 6 else False)

df_alunos
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_Finais  \
# 0         Ary     20    7.5      True           3.00         10.50
# 1         Ana     18    0.0     False           0.00          0.00
# 2       Cátia     27    2.5     False           1.00          3.50
# 3       Denis     18    5.0     False           2.00          7.00
# 4        Beto     21   10.0      True           4.00         14.00
# 5       Bruna     23    0.0     False           0.00          0.00
# 6        Dara     21    7.0      True           2.80          9.80
# 7      Carlos     19    6.0      True           2.40          8.40
# 8       Alice     35    5.6     False           2.24          7.84
# 9       Vitor     28    0.0     False           0.00          0.00
# 10     Daniel     21    0.0     False           0.00          0.00
# 11       Igor     24    4.5     False           1.80          6.30
# 12  Sthefanie     26    9.5      True           3.80         13.30
# ...

# %% [markdown]
# **4) Faça uma seleção e verifique quais alunos não tinham sido aprovados anteriormente, mas foram aprovados após a soma dos pontos extras.**

# %%
df_alunos.query('Aprovado == False & Aprovado_Final == True')
# Out:
#      Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_Finais  Aprovado_Final
# 3   Denis     18    5.0     False           2.00          7.00            True
# 8   Alice     35    5.6     False           2.24          7.84            True
# 11   Igor     24    4.5     False           1.80          6.30            True

# %%
df_alunos.to_csv('Alunos_Aprovados_Final.csv')
